# %%
import pandas as pd 
df1 = pd.read_csv("./data/1000000-bandcamp-sales.csv")

# %%
df1.head()
# Out:
#    Unnamed: 0                                                _id  \
# 0           0  1599688803.5175&//girlbanddublin.bandcamp.com/...
# 1           1  1599688805.27838&//maharettarecords.bandcamp.c...
# 2           2  1599688805.90646&//maharettarecords.bandcamp.c...
# 3           3  1599688806.94234&//alicesitski.bandcamp.com/al...
# 4           4  1599688809.07942&//linguaignota.bandcamp.com/t...
#
#                                        art_url item_type      utc_date  \
# 0  https://f4.bcbits.com/img/a0206405257_7.jpg         a  1.599689e+09
# 1  https://f4.bcbits.com/img/a2984241552_7.jpg         a  1.599689e+09
# 2  https://f4.bcbits.com/img/a3320494770_7.jpg         a  1.599689e+09
# 3  https://f4.bcbits.com/img/0020476345_37.jpg         p  1.599689e+09
# 4  https://f4.bcbits.com/img/a3428873396_7.jpg         t  1.599689e+09
#
#   country_code track_album_slug_text         country slug_type  \
# 0           gb                   NaN  United Kingdom         a
# ...

# %%
import pandas as pd 
df = pd.read_csv("./data/location.csv", encoding="ISO-8859-1",sep='|')

# %%
import random

import numpy as np


vl = df['locate_id'].values.tolist()
shuffled_values=np.random.permutation(vl * 300)[:1000000]
df2 = pd.DataFrame({'location': shuffled_values})

# %%
df1['location'] = df2['location']

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', '_id', 'art_url', 'item_type', 'utc_date', 'country_code',
#        'track_album_slug_text', 'country', 'slug_type', 'amount_paid_fmt',
#        'item_price', 'item_description', 'art_id', 'url', 'amount_paid',
#        'releases', 'artist_name', 'currency', 'album_title', 'amount_paid_usd',
#        'package_image_id', 'amount_over_fmt', 'item_slug', 'addl_count'],
#       dtype='object')

# %%
df1.drop(columns=['Unnamed: 0','country','country_code'])
# Out:
#                                                       _id  \
# 0       1599688803.5175&//girlbanddublin.bandcamp.com/...
# 1       1599688805.27838&//maharettarecords.bandcamp.c...
# 2       1599688805.90646&//maharettarecords.bandcamp.c...
# 3       1599688806.94234&//alicesitski.bandcamp.com/al...
# 4       1599688809.07942&//linguaignota.bandcamp.com/t...
# ...                                                   ...
# 999995  1601647409.59517&//eternalchampion.bandcamp.co...
# 999996  1601647409.61911&//goodmusic2020.bandcamp.com/...
# 999997  1601647409.63413&//geometriclullaby.bandcamp.c...
# 999998  1601647409.77243&//bewitcher.bandcamp.com/merc...
# 999999  1601647410.21167&//jonsi.bandcamp.com/album/sh...
#
#                                             art_url item_type      utc_date  \
# 0       https://f4.bcbits.com/img/a0206405257_7.jpg         a  1.599689e+09
# 1       https://f4.bcbits.com/img/a2984241552_7.jpg         a  1.599689e+09
# ...

# %%
df1.to_csv('1000000-bandcamp-sales.csv',index=False)
